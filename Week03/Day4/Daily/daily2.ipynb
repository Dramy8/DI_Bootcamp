# %% [markdown]
# <a href="https://colab.research.google.com/github/Dramy8/DI_Bootcamp/blob/main/Week03/Day4/Daily/daily2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install googletrans==4.0.0-rc1

from googletrans import Translator
translator = Translator()

translated = translator.translate('Бороди́нское сраже́ние')

print(translated.text)
# Out:
# ...
# Battle of Borodino

# %% [markdown]
# Instructions :
# Consider this list
#
# french_words= ["Bonjour", "Au revoir", "Bienvenue", "A bientôt"]
# Look at this result :
# {"Bonjour": "Hello", "Au revoir": "Goodbye", "Bienvenue": "Welcome", "A bientôt": "See you soon"}
# You have to recreate the result using a translator module. Take a look at the googletrans module.

# %%
translator = Translator()

translated = translator.translate('Bonjour comment tu vas')

print(translated.text)
# Out:
# Hello, how are you

# %%
french_words= ["Bonjour", "Au revoir", "Bienvenue", "A bientôt"]

for word in french_words:
  translated = translator.translate(word, src="fr", dest="en")
  trad = {}
  trad[word] = translated.text
  print(trad)
# Out:
# {'Bonjour': 'Good morning'}
# {'Au revoir': 'Bye'}
# {'Bienvenue': 'Welcome'}
# {'A bientôt': 'See you soon'}
