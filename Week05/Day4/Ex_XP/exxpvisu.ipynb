# %% [markdown]
# <a href="https://colab.research.google.com/github/Dramy8/DI_Bootcamp/blob/main/Week05/Day4/Ex_XP/exxpvisu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🌟 Exercise 1: Understanding Data Visualization
# Task: Explain why data visualization is important in data analysis.
# Task: Describe the purpose of a line graph in data visualization.
#
#
# Why is data visualization important in data analysis?
# Data visualization is important because it makes data easier to understand. Charts and graphs help us quickly identify patterns, trends, comparisons, and unusual values that may be difficult to notice in a table of numbers. It also helps communicate findings clearly to others.
#
# What is the purpose of a line graph?
# A line graph is used to show how a value changes over time or across another ordered sequence. It is especially useful for identifying trends, such as whether sales, temperatures, or website visits are increasing, decreasing, or fluctuating.

# %% [markdown]
# 🌟 Exercise 2: Creating a Line Plot for Temperature Variation
# Objective: Create a simple line plot using Matplotlib that represents temperature variations over a week.
# Tasks:
# Use a list of temperature values for each day of the week (e.g., [72, 74, 76, 80, 82, 78, 75]).
# Label the x-axis as “Day” and the y-axis as “Temperature (°F)”.
# Add a title to the plot.
# Display the plot.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Define dataset coordinates
x = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
y = [72, 74, 76, 80, 82, 78, 75]

# Initialize figure and axes object
fig, ax = plt.subplots()

# Render line plot
ax.plot(x, y)

# Add metadata annotations
ax.set_title("Temperature variations over a week")
ax.set_xlabel("Day")
ax.set_ylabel("Temperature")

# Render visualization output window
plt.show()

# %% [markdown]
# 🌟 Exercise 3: Visualizing Monthly Sales with a Bar Chart
# Objective: Generate a bar chart using Matplotlib to visualize monthly sales data for a retail store.
# Tasks:
# Create a list of sales values for each month (e.g., [5000, 5500, 6200, 7000, 7500]).
# Label the x-axis as “Month” and the y-axis as “Sales Amount ($)”.
# Add a title to the bar chart.
# Display the plot.

# %%
# Dataset
month = ['Jan', 'Feb', 'March', 'Apr', 'May', 'June', 'July', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']
sales = [5000, 5500, 6200, 7000, 7500, 5000, 8500, 9000, 5000, 7000, 10500, 11000]


# Create figure
plt.figure(figsize=(6, 4))

# Plot vertical bars
plt.bar(month, sales, color='skyblue', edgecolor='black', width=0.6)

# Add titles and labels
plt.title('Monthly sales data')
plt.xlabel('Month')
plt.ylabel('Sales')

# Render the plot
plt.show()

# %% [markdown]
#   🌟 Exercise 4: Visualizing the Distribution of CGPA
# Objective: Create a histogram to visualize the distribution of students’ CGPA.
# Dataset Overview: Assume the CGPA data is categorized into ranges and loaded in a DataFrame named df.
# Tasks:
# Import necessary libraries.
# Use Seaborn’s histplot to create a histogram of the CGPA categories.
# Customize the histogram with a specific color and add a title.
# Display the plot.

# %%
df= pd.read_csv("Student Mental health.csv")

# %%
df
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# 0                       year 1        3.00 - 3.49             No
# 1                       year 2        3.00 - 3.49             No
# 2                       Year 1        3.00 - 3.49             No
# 3                       year 3        3.00 - 3.49            Yes
# 4                       year 4        3.00 - 3.49             No
# ..                         ...                ...            ...
# 96                      year 1        3.50 - 4.00             No
# 97                      Year 2        3.00 - 3.49             No
# 98                      Year 3        3.50 - 4.00            Yes
# 99                      year 4        3.50 - 4.00             No
# 100                     Year 2        3.00 - 3.49             No
#
#     Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                       Yes                   No                       Yes
# 1                        No                  Yes                        No
# 2                       Yes                  Yes                       Yes
# 3                       Yes                   No                        No
# 4                        No                   No                        No
# ..                      ...                  ...                       ...
# 96                       No                  Yes                        No
# 97                      Yes                  Yes                        No
# 98                      Yes                   No                       Yes
# 99                       No                   No                        No
# 100                      No                   No                        No
#
#     Did you seek any specialist for a treatment?
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
# ..                                           ...
# 96                                            No
# 97                                            No
# 98                                            No
# 99                                            No
# 100                                           No
#
# [101 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Timestamp', 'Choose your gender', 'Age', 'What is your course?',
#        'Your current year of Study', 'What is your CGPA?', 'Marital status',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?',
#        'Did you seek any specialist for a treatment?'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Timestamp                                     101 non-null    object
#  1   Choose your gender                            101 non-null    object
#  2   Age                                           100 non-null    float64
#  3   What is your course?                          101 non-null    object
#  4   Your current year of Study                    101 non-null    object
#  5   What is your CGPA?                            101 non-null    object
#  6   Marital status                                101 non-null    object
#  7   Do you have Depression?                       101 non-null    object
#  8   Do you have Anxiety?                          101 non-null    object
#  9   Do you have Panic attack?                     101 non-null    object
#  10  Did you seek any specialist for a treatment?  101 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 8.8+ KB

# %%
sns.histplot(
    data=df,
    x='What is your CGPA?',
    discrete=True,
    color='skyblue'
)

plt.title('Distribution of CGPA')
plt.xlabel('CGPA range')
plt.ylabel('Number of students')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# 🌟 Exercise 5: Comparing Anxiety Levels Across Different Genders
# Objective: Use a bar plot to compare the proportion of students experiencing anxiety across different genders.
# Dataset Overview: The dataset includes columns: ‘Do you have Anxiety?’ and ‘Choose your gender’.
# Tasks:
# Import necessary libraries.
# Use Seaborn to create a bar plot comparing anxiety levels across genders from the dataset df.
# Customize the plot with an appropriate color palette and add a title.
# Display the plot.

# %%
counts = (
    df.groupby(['Do you have Anxiety?', 'Choose your gender'])
      .size()
      .reset_index(name='count')
)

sns.barplot(
    data=counts,
    x='Do you have Anxiety?',
    y='count',
    hue='Choose your gender'
)

plt.title('Anxiety Responses by Gender')
plt.xlabel('Anxiety')
plt.ylabel('Number of students')
plt.legend(title='Gender')

plt.show()

# %% [markdown]
# 🌟 Exercise 6: Exploring the Relationship Between Age and Panic Attacks
# Objective: Create a scatter plot to explore the relationship between students’ age and the occurrence of panic attacks.
# Dataset Overview: The dataset includes columns: ‘Age’ and ‘Do you have Panic Attacks?’.
# Tasks:
# Import necessary libraries.
# Convert panic attack responses to numeric values (e.g., Yes=1, No=0).
# Use Seaborn’s scatterplot to create a scatter plot with ‘Age’ on the x-axis and numeric panic attack responses on the y-axis.
# Customize the plot to improve readability by adding labels, a title, and adjusting point styles.
# Display the plot.

# %%
df['panic_attack_num'] = df['Do you have Panic attack?'].map({
    'Yes': 1,
    'No': 0
})

sns.scatterplot(
    data=df,
    x='Age',
    y='panic_attack_num',
    alpha=0.5,
    s=70
)

plt.title('Relationship Between Age and Panic Attacks')
plt.xlabel('Age')
plt.ylabel('Panic attacks')
plt.yticks([0, 1], ['No', 'Yes'])

plt.show()
